# %%
import pandas as pd
# %matplotlib inline
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Full_Test.csv')

# %%
df.head()
# Out:
#              Type                       Meter     Date Start Time   Usage  \
# 0  Electric Usage  A71 Mitchell Hospital (B1)  4/11/14      23:30  433.44
# 1  Electric Usage  A71 Mitchell Hospital (B1)  4/12/14       0:00  432.36
# 2  Electric Usage  A71 Mitchell Hospital (B1)  4/12/14       0:30  435.24
# 3  Electric Usage  A71 Mitchell Hospital (B1)  4/12/14       1:00  433.80
# 4  Electric Usage  A71 Mitchell Hospital (B1)  4/12/14       1:30  428.76
#
#   Usage Unit  Temperature Temperature Unit
# 0        kWh          NaN                F
# 1        kWh           52                F
# 2        kWh           52                F
# 3        kWh           55                F
# 4        kWh           55                F

# %%
meters = df.Meter.unique()

# %%
data=df[df['Meter'].isin(['A71 Mitchell Hospital (B1)'])]
sns.distplot(data.Usage)

# %%
sns.set_style("darkgrid")
plt.plot(data.Usage)
